# %% [markdown]
# # **Module - 1 : Python Basics**

# %% [markdown]
# Data types in python, **Operators in python**, Input and Output,
# Control statements, Arrays in python, String and Character in python, Functions, List and Tuples, Dictionaries Exception, Introduction to OOP, Classes, Objects, Interfaces, Inheritance

# %% [markdown]
# # **Operators**
# Operators are used to perform operations on variables and values.
# Python divides the operators in the following groups:
#
# * Arithmetic operators
# * Bitwise operators
# * Comparison operators
# * Logical operators
# * Identity operators
# * Membership operators
# * Assignment operators

# %% [markdown]
# **Arithmetic operators** are used with numeric values to perform common mathematical operations:

# %%
x,y = 19,3
print("x =", x)
print("y =", y)
print("x + y = ",x+y)  # Addition
print("x - y =",x-y)  # Subtraction
print("x / y =",x/y)  # Division
print("x * y =",x*y)  # Multiplication
print("x % y =",x%y)  # Modulo Division
print("x ** y =",x**y) # Exponetiation
print("x // y =",x//y) # Floor Division

# %% [markdown]
# **Bitwise operators** are used to compare (binary) numbers:
# ![bitwise_py.png](data:image/png;base64,...)

# %% [markdown]
# **Comparison operators** are used to compare two values:
#
# ![compare_py.png](data:image/png;base64,...)

# %% [markdown]
# **Logical operators** are used to combine conditional statements:
# ![logical_py.png](data:image/png;base64,...)

# %% [markdown]
# **Identity operators** are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:
#
# ![identity_py.png](data:image/png;base64,...)

# %%
x = 5
y = 5
print(id(x))
print(id(y))
print(x is y)
print(x is not y)
# Out:
# 94243449612928
# 94243449612928
# True
# False

# %% [markdown]
# **Membership operators** are used to test if a sequence is presented in an object:
# ![membership_py.png](data:image/png;base64,...)

# %% [markdown]
# **Assignment operators** are used to assign values to variables:

# %%
# You cannot use statements inside the print statement , 
# that is why you get the syntax error. You can only use Expressions there.
x = 5
print(x+=3)	# x = x + 3

# %%
x = 5
x += 3	# x = x + 3	
print(x)
# Out:
# 8

# %%
x = 5
x -= 3	# x = x - 3	
print(x)
# Out:
# 2

# %%
x = 5
x *= 3	# x = x * 3	
print(x)
# Out:
# 15

# %%
x = 5
x /= 3	# x = x / 3	
print(x)
# Out:
# 1.6666666666666667

# %%
x = 5
x %= 3	# x = x % 3	
print(x)
# Out:
# 2

# %%
x = 5
x //= 3	# x = x // 3	
print(x)
# Out:
# 1

# %%
x = 5
x **= 3	# x = x ** 3	
print(x)
# Out:
# 125

# %%
x = 5
x &= 3	# x = x & 3	
print(x)
# Out:
# 1

# %%
x = 5
x |= 3	# x = x | 3	
print(x)
# Out:
# 7

# %%
x = 5 
x ^= 3	# x = x ^ 3	
print(x)
# Out:
# 6

# %%
x = 5
x >>= 3	# x = x >> 3	
print(x)
# Out:
# 0

# %%
x = 5
x <<= 3	# x = x << 3
print(x)
# Out:
# 40

# %% [markdown]
# # **Digital material:**

# %% [markdown]
# 1. "The Python Tutorial",http://docs.python.org/release/3.0.1/tutorial/
# 2. Beginning Perl,https://www.perl.org/books/beginning-perl/
# 3. http://spoken-tutorial.org
# 4. https://starcertification.org/Certifications/Certificate/python
# 5. https://www.python.org/downloads/
# 6. http://anandology.com/python-practice-book/getting-started.html
# 7. https://learnpythonthehardway.org/book/ex1.html
# 8. https://www.udemy.com/course/learn-python-with-google-colab-a-step-to-machine-learning/
# 9. https://www.w3schools.com/python/
# 10. https://www.geeksforgeeks.org/python-output-using-print-function/?ref=lbp
